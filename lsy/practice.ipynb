# %%
import pandas as pd

# %%
nanji = pd.read_csv("/Users/limsoyeon/nanji_work/ksm/nanji_hourly_modeling/nanji_hourly_model_dataset_2020_2026.csv")

# %%
nanji
# Out:
#                   datetime        date  hour  year  month  day day_of_week  \
# 0      2020-02-11 00:00:00  2020-02-11     0  2020      2   11     Tuesday
# 1      2020-02-11 01:00:00  2020-02-11     1  2020      2   11     Tuesday
# 2      2020-02-11 02:00:00  2020-02-11     2  2020      2   11     Tuesday
# 3      2020-02-11 03:00:00  2020-02-11     3  2020      2   11     Tuesday
# 4      2020-02-11 04:00:00  2020-02-11     4  2020      2   11     Tuesday
# ...                    ...         ...   ...   ...    ...  ...         ...
# 53491  2026-04-02 19:00:00  2026-04-02    19  2026      4    2    Thursday
# 53492  2026-04-02 20:00:00  2026-04-02    20  2026      4    2    Thursday
# 53493  2026-04-02 21:00:00  2026-04-02    21  2026      4    2    Thursday
# 53494  2026-04-02 22:00:00  2026-04-02    22  2026      4    2    Thursday
# 53495  2026-04-02 23:00:00  2026-04-02    23  2026      4    2    Thursday
#
# ...

# %%
nanji.describe()
# Out:
#                hour          year         month           day  \
# count  53496.000000  53496.000000  53496.000000  53496.000000
# mean      11.500000   2022.698520      6.434275     15.761328
# std        6.922251      1.787944      3.459314      8.796749
# min        0.000000   2020.000000      1.000000      1.000000
# 25%        5.750000   2021.000000      3.000000      8.000000
# 50%       11.500000   2023.000000      6.000000     16.000000
# 75%       17.250000   2024.000000      9.000000     23.000000
# max       23.000000   2026.000000     12.000000     31.000000
#
#        daily_parking_count  daily_usage_minutes  avg_stay_minutes  \
# count         53496.000000         53496.000000      53496.000000
# mean           1764.861373        110642.064603         57.841299
# std             751.124751         83533.976606         20.461665
# min              49.000000             0.000000          0.000000
# 25%            1301.000000         59312.000000         44.500564
# ...

# %%
nanji.columns
# Out:
# Index(['datetime', 'date', 'hour', 'year', 'month', 'day', 'day_of_week',
#        'is_weekend', 'season', 'daily_parking_count', 'daily_usage_minutes',
#        'avg_stay_minutes', 'hourly_share', 'estimated_entries',
#        'estimated_active_cars', 'estimated_active_cars_change',
#        'holiday_table_is_weekend', 'holiday_name', 'is_holiday',
#        'is_substitute_holiday', 'is_holiday_or_weekend', 'is_long_weekend',
#        'bus_boardings', 'bus_alightings', 'subway_boardings',
#        'subway_alightings', 'bike_rentals', 'bike_rental_minutes_sum',
#        'bike_rental_distance_m_sum', 'bike_returns', 'event_count',
#        'free_event_count', 'paid_event_count', 'evening_event_count',
#        'nearby_public_parking_sites', 'nearby_public_parking_capacity_sum',
#        'nearby_kickboard_zone_count', 'nearby_kickboard_stand_count',
#        'bus_feature_available', 'subway_feature_available',
#        'bike_feature_available', 'culture_feature_available'],
# ...

# %%
nanji['estimated_entries'].plot()
# Out:
# <Axes: >

# %%
nanji['estimated_active_cars'].plot()
# Out:
# <Axes: >

# %%
nanji[['estimated_entries', 'estimated_active_cars']].plot(kind='line', figsize=(40,5), title='Estimated Active Cars Over Time')
# Out:
# <Axes: title={'center': 'Estimated Active Cars Over Time'}>
