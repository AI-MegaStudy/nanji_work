# %%
import requests

url = "https://api.odcloud.kr/api/15150101/v1/uddi:1ddc788e-fdd8-4255-9e6d-a8f260dc20db"

params = {
    "serviceKey": "15150101/v1/uddi:1ddc788e-fdd8-4255-9e6d-a8f260dc20db",
    "page": 1,
    "perPage": 100
}

response = requests.get(url, params=params)

if response.status_code == 200:
    data = response.json()
    print(data)
else:
    print("요청 실패:", response.status_code, response.text)
# Out:
# 요청 실패: 400 {"code":-4,"msg":"등록되지 않은 인증키 입니다."}

# %%
import requests

url = "https://api.odcloud.kr/api/15150101/v1/uddi:1ddc788e-fdd8-4255-9e6d-a8f260dc20db"

headers = {
    "Authorization": "0880e7e2034682300021cc8538907c62995d2d59781429d7b09da9d977b68cd9"
}

params = {
    "page": 1,
    "perPage": 10
}

response = requests.get(url, headers=headers, params=params)

print(response.status_code)
print(response.text)
# Out:
# 401
# {"code":-401,"msg":"인증키는 필수 항목 입니다."}
